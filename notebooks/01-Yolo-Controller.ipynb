# %%
import subprocess
import matplotlib

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
stdout = subprocess.check_output('nvidia-smi')
for line in stdout.strip().decode().splitlines():
    print(line)
# Out:
# Fri May  3 15:25:49 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 410.104      Driver Version: 410.104      CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           On   | 00000000:00:1E.0 Off |                    0 |
# | N/A   46C    P0    72W / 149W |    775MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    0     31415      C   ...u/anaconda3/envs/pytorch_p36/bin/python   764MiB |
# +-----------------------------------------------------------------------------+

# %%
from detector import detector

# %%
class Opt:
    image_folder = 'data/images'
    show_img = True
    
    model_def = "config/yolov3.cfg"
    weights_path = "weights/yolov3.weights"
    class_path = "data/coco.names"
    
    conf_thres = 0.8
    nms_thres = 0.4
    batch_size = 1
    n_cpu = 0
    img_size = 416
    
    
opt = Opt()

imgs, dets = detector(opt)
# Out:
# ============================================================
#                      STARTING DETECTOR
# ============================================================
#
# config/yolov3.cfg
#
# Performing object detection:
# 	+ Batch 0, Inference Time: 0:00:00.258765
# 	+ Batch 1, Inference Time: 0:00:00.107677
#
# Saving images:
# (0) Image: 'data/images/bottle.JPG'
# 	+ Label: cup, Conf: 0.98516
# 	+ Label: bottle, Conf: 0.99805
# (1) Image: 'data/images/bottles.JPG'
# 	+ Label: bottle, Conf: 0.99972
# 	+ Label: bottle, Conf: 0.99992
# 	+ Label: bottle, Conf: 0.99962
# 	+ Label: bottle, Conf: 0.99977
# 	+ Label: bottle, Conf: 0.99988
# 	+ Label: bottle, Conf: 0.99985
